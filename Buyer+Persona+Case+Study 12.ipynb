# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_excel(r'C:\Users\mayur\Downloads\Buyer+Persona+Case+Study 12.xlsx', sheet_name='Sample Retail Data')

# %%
df
# Out:
#            Date      Time             Category  Qty Price Point Name     SKU  \
# 0    2018-08-09  13:10:19            Furniture    1          Regular  1109.0
# 1    2018-06-15  13:02:06            Furniture    1          Regular  1184.0
# 2    2018-04-07  13:41:01            Furniture    1              NaN   260.0
# 3    2017-10-13  18:23:13            Furniture    1              NaN   401.0
# 4    2018-03-02  11:48:33            Furniture    1          Regular   953.0
# ...         ...       ...                  ...  ...              ...     ...
# 2871 2018-01-13  14:51:15  Vintage Accessories   -1              NaN   184.0
# 2872 2018-04-12  13:02:58  Handmade - Textiles   -1          Regular  1040.0
# 2873 2018-02-10  16:06:55     Vintage Clothing   -1              NaN   715.0
# 2874 2018-04-12  13:02:58  Handmade - Textiles   -1          Regular  1038.0
# 2875 2017-12-02  12:34:19  Handmade - Textiles   -1              NaN   492.0
#
# ...

# %%
df.shape
# Out:
# (2876, 16)

# %%
df.head()
# Out:
#         Date      Time   Category  Qty Price Point Name     SKU  Gross Sales  \
# 0 2018-08-09  13:10:19  Furniture    1          Regular  1109.0       298.99
# 1 2018-06-15  13:02:06  Furniture    1          Regular  1184.0       270.00
# 2 2018-04-07  13:41:01  Furniture    1              NaN   260.0       240.00
# 3 2017-10-13  18:23:13  Furniture    1              NaN   401.0       225.00
# 4 2018-03-02  11:48:33  Furniture    1          Regular   953.0       205.00
#
#    Discounts                 Customer ID   Cost  Margin  Gender    Age State  \
# 0        0.0  S0Q2DVVJW55BCZEN1Q8MA4APVC  80.95    0.73    Male  18-25    NC
# 1        0.0  M90BSKQPTD7MRJHDHD7DD8T6CG  80.95    0.70  Female  26-35    NC
# 2        0.0  AAAPTRXCWD2FYVE6Y2K7WJRKDR  80.95    0.66  Female  36-45    NC
# 3        0.0  CY4R1654M966EJCJN5X1B6K10G  80.95    0.64  Female  46-55    NC
# 4        0.0  N55H0JCHJN428N7Z8T98XP32KR  80.95    0.61  Female  56-64    NC
#
#    ABC  XYZ
# 0  NaN  NaN
# 1  NaN  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2876 entries, 0 to 2875
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              2876 non-null   datetime64[ns]
#  1   Time              2876 non-null   object
#  2   Category          2833 non-null   object
#  3   Qty               2876 non-null   int64
#  4   Price Point Name  1194 non-null   object
#  5   SKU               2873 non-null   float64
#  6   Gross Sales       2876 non-null   float64
#  7   Discounts         2876 non-null   float64
#  8   Customer ID       2850 non-null   object
#  9   Cost              2876 non-null   float64
#  10  Margin            2876 non-null   float64
#  11  Gender            2850 non-null   object
#  12  Age               2850 non-null   object
#  13  State             2850 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(7)
# memory usage: 314.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2876 entries, 0 to 2875
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              2876 non-null   datetime64[ns]
#  1   Time              2876 non-null   object
#  2   Category          2833 non-null   object
#  3   Qty               2876 non-null   int64
#  4   Price Point Name  1194 non-null   object
#  5   SKU               2873 non-null   float64
#  6   Gross Sales       2876 non-null   float64
#  7   Discounts         2876 non-null   float64
#  8   Customer ID       2850 non-null   object
#  9   Cost              2876 non-null   float64
#  10  Margin            2876 non-null   float64
#  11  Gender            2850 non-null   object
#  12  Age               2850 non-null   object
#  13  State             2850 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(7)
# memory usage: 314.7+ KB

# %%
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# Date                0
# Time                0
# Category            0
# Qty                 0
# Price Point Name    0
# SKU                 0
# Gross Sales         0
# Discounts           0
# Customer ID         0
# Cost                0
# Margin              0
# Gender              0
# Age                 0
# State               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Category', 'Qty', 'Price Point Name', 'SKU',
#        'Gross Sales', 'Discounts', 'Customer ID', 'Cost', 'Margin', 'Gender',
#        'Age', 'State'],
#       dtype='object')

# %%
df.describe()
# Out:
#                                 Date          Qty          SKU  Gross Sales  \
# count                           1181  1181.000000  1181.000000  1181.000000
# mean   2018-05-23 15:03:30.330228480     1.089754   913.651990    18.596012
# min              2017-10-12 00:00:00    -1.000000     1.000000   -28.000000
# 25%              2018-03-13 00:00:00     1.000000   533.000000     6.990000
# 50%              2018-06-09 00:00:00     1.000000   908.000000    15.000000
# 75%              2018-08-17 00:00:00     1.000000  1191.000000    23.000000
# max              2018-10-12 00:00:00     7.000000  1743.000000   298.990000
# std                              NaN     0.412193   384.462198    21.518562
#
#          Discounts         Cost       Margin
# count  1181.000000  1181.000000  1181.000000
# mean     -0.934115     7.551668     0.527722
# min     -25.650000     1.990000    -2.980000
# 25%      -0.800000     1.990000     0.450000
# 50%       0.000000     5.460000     0.560000
# ...

# %%
df[['Date','Qty','Cost']].describe()
# Out:
#                                 Date          Qty         Cost
# count                           1181  1181.000000  1181.000000
# mean   2018-05-23 15:03:30.330228480     1.089754     7.551668
# min              2017-10-12 00:00:00    -1.000000     1.990000
# 25%              2018-03-13 00:00:00     1.000000     1.990000
# 50%              2018-06-09 00:00:00     1.000000     5.460000
# 75%              2018-08-17 00:00:00     1.000000     9.980000
# max              2018-10-12 00:00:00     7.000000   102.340000
# std                              NaN     0.412193    10.716776

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Category', 'Qty', 'Price Point Name', 'SKU',
#        'Gross Sales', 'Discounts', 'Customer ID', 'Cost', 'Margin', 'Gender',
#        'Age', 'State'],
#       dtype='object')

# %%
ax = sns.countplot(x = 'Gender',data = df) 

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Cost'].sum().sort_values(by='Cost', ascending=False)

sns.barplot(x = 'Gender',y= 'Cost' ,data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Cost'>

# %%
ax = sns.countplot(data = df,x = 'Age', hue ='Gender')

for bar in ax.cointainers:
    ax.bar_label(bars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[363], line 3
#       1 ax = sns.countplot(data = df,x = 'Age', hue ='Gender')
# ----> 3 for bar in ax.cointainers:
#       4     ax.bar_label(bars)
#
# AttributeError: 'Axes' object has no attribute 'cointainers'

# %%
sales_age = df.groupby(['Age'], as_index=False)['Cost'].sum().sort_values(by='Cost', ascending=False)

sns.barplot(x = 'Age',y= 'Cost' ,data = sales_age)
# Out:
# <Axes: xlabel='Age', ylabel='Cost'>

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Category', 'Qty', 'Price Point Name', 'SKU',
#        'Gross Sales', 'Discounts', 'Customer ID', 'Cost', 'Margin', 'Gender',
#        'Age', 'State'],
#       dtype='object')

# %%
sales_state = df.groupby(['State'], as_index=False)['Gross Sales'].sum().sort_values(by='Gross Sales', ascending=False).head(10)

sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Gross Sales')
# Out:
# <Axes: xlabel='State', ylabel='Gross Sales'>

# %%
sales_state = df.groupby(['State'], as_index=False)['Discounts'].sum().sort_values(by='Discounts', ascending=False).head(10)

sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(data = sales_state, x = 'State',y = 'Discounts')
# Out:
# <Axes: xlabel='State', ylabel='Discounts'>

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Category', 'Qty', 'Price Point Name', 'SKU',
#        'Gross Sales', 'Discounts', 'Customer ID', 'Cost', 'Margin', 'Gender',
#        'Age', 'State'],
#       dtype='object')

# %%
ax = sns.countplot(data = df, x = 'Category')

sns.set(rc={'figure.figsize':(37,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Category'], as_index=False)['Cost'].sum().sort_values(by='Cost', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Category',y= 'Cost')
# Out:
# <Axes: xlabel='Category', ylabel='Cost'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(10,7))
df.groupby('Date')['Gross Sales'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>
